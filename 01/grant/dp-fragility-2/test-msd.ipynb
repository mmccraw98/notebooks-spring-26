# %%
import matplotlib.pyplot as plt
import numpy as np
from file_management import load_arrs
from config import config2d_soft as cfg

# %%
data = load_arrs(
    '/Users/marshallmccraw/Projects/yale/data/s-26/grant/dp-fragility/2d-soft/phi-0.537377/traj/data.h5'
)
ke = data['ke']
pe = data['pe']
# pos_dp = data['pos_dp']
# vel_dp = data['vel_dp']
# msd = data['msd']

# dim = 2  # spatial dimension
# sigma = 1.0  # particle diameter
# time_unit = sigma * np.sqrt(cfg.mass / cfg.e_int)
# t = data['t_dimless'] * cfg.dt * cfg.save_stride

# plt.plot(pe)
# plt.plot(ke)
plt.plot(pe + ke)
