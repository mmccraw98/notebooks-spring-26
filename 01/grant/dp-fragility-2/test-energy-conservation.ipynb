# %%
import numpy as np
import matplotlib.pyplot as plt
from file_management import load_arrs
import os

# %%
root = '/home/mmccraw/dev/data/26-01-01/grant/dp-fragility/2d-med'

norm = plt.Normalize(0.6, 0.6005)
cmap = plt.cm.viridis

fig, ax = plt.subplots(1, 4, figsize=(8, 3), constrained_layout=True)

phis = []
kes = []

for phi in os.listdir(root):
    phi_float = float(phi.split('-')[-1])
    c = cmap(norm(phi_float))
    try:
        data = load_arrs(
            os.path.join(root, phi, 'traj', 'data.h5')
        )
    except:
        continue
    ax[0].plot(data['t_dimless'], data['msd'], c=c)
    ax[1].plot(data['t_dimless'], data['isf'], c=c)
    te = data['pe'] + data['ke']
    kes.append(data['ke'])
    phis.append(phi_float)
    ax[2].scatter(phi_float, np.std(te) / np.mean(te), c=c)
    ax[3].scatter(phi_float, np.mean(data['ke']) / 2700, c=c)
for a in ax[:2]:
    a.set_xscale('log')
ax[0].set_yscale('log')
ax[2].set_yscale('log')
ax[3].set_yscale('log')
plt.show()

plt.plot(np.concatenate([kes[i] for i in np.argsort(phis)]))
# Out:
# /tmp/ipykernel_2515135/2043952617.py:25: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax[2].scatter(phi_float, np.std(te) / np.mean(te), c=c)
# /tmp/ipykernel_2515135/2043952617.py:26: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax[3].scatter(phi_float, np.mean(data['ke']) / 2700, c=c)

# %%
# Out:
# np.float64(9.57109754371373e-05)

# %%
root = '/home/mmccraw/dev/data/26-01-01/grant/dp-fragility-all-in-one/2d-med'

norm = plt.Normalize(0.6, 0.6005)
cmap = plt.cm.viridis

fig, ax = plt.subplots(1, 4, figsize=(8, 3), constrained_layout=True)

phis = []
kes = []

for phi in os.listdir(root):
    phi_float = float(phi.split('-')[-1])
    c = cmap(norm(phi_float))
    try:
        data = load_arrs(
            os.path.join(root, phi, 'traj', 'data.h5')
        )
    except:
        continue
    ax[0].plot(data['t_dimless'], data['msd'], c=c)
    ax[1].plot(data['t_dimless'], data['isf'], c=c)
    te = data['pe'] + data['ke']
    kes.append(data['ke'])
    phis.append(phi_float)
    ax[2].scatter(phi_float, np.std(te) / np.mean(te), c=c)
    ax[3].scatter(phi_float, np.mean(data['ke']) / 2700, c=c)
for a in ax[:2]:
    a.set_xscale('log')
ax[0].set_yscale('log')
ax[2].set_yscale('log')
ax[3].set_yscale('log')
plt.show()

plt.plot(np.concatenate([kes[i] for i in np.argsort(phis)]))
# Out:
# /tmp/ipykernel_2509053/3880666939.py:25: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax[2].scatter(phi_float, np.std(te) / np.mean(te), c=c)
# /tmp/ipykernel_2509053/3880666939.py:26: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax[3].scatter(phi_float, np.mean(data['ke']) / 2700, c=c)
